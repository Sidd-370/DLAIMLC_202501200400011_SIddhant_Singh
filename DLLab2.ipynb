# %%
# Step 1: Given Data
X = [75, 65, 80]          # Inputs
w = [4, 3, 5]             # Initial weights
b = -1000                 # Bias
eta = 0.01                # Learning rate
y = 1                     # Target output (Pass = 1)

# Step function (activation)
def step_function(z):
    if z >= 0:
        return 1
    else:
        return 0

print("BEFORE LEARNING")

# Step 2: Calculate Net input
z = (w[0]*X[0]) + (w[1]*X[1]) + (w[2]*X[2]) + b
print("Net input z =", z)

# Step 3: Activation
y_pred = step_function(z)
print("Prediction =", "Pass" if y_pred == 1 else "Fail")

# Step 4: Error
error = y - y_pred
print("Error =", error)

if error != 0:
    # Step 5: Weight update
    w[0] = w[0] + eta * error * X[0]
    w[1] = w[1] + eta * error * X[1]
    w[2] = w[2] + eta * error * X[2]

    # Step 6: Bias update
    b = b + eta * error

print("\nAFTER LEARNING")

z_new = (w[0]*X[0]) + (w[1]*X[1]) + (w[2]*X[2]) + b
print("Net input z =", z_new)

y_pred_new = step_function(z_new)
print("Prediction =", "Pass" if y_pred_new == 1 else "Fail")

print("\nUpdated Weights:", w)
print("Updated Bias:", b)
# Out:
# BEFORE LEARNING
# Net input z = -105
# Prediction = Fail
# Error = 1
#
# AFTER LEARNING
# Net input z = 57.50999999999999
# Prediction = Pass
#
# Updated Weights: [4.75, 3.65, 5.8]
# Updated Bias: -999.99
