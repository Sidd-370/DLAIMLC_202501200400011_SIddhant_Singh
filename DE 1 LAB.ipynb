# %%
import numpy as np
import tensorflow as tf

#Step1: convert data to Numpy array
x = np.array([1,2,3,4], dtype = float);
y = np.array([2,4,6,8], dtype = float);

#step2: Define model using Input layer(recommended)

model = tf.keras.Sequential([
tf.keras.Input(shape = (1,)),     #preferred over input shape in dense
tf.keras.layers.Dense(1)
])

#Step 3: Compile the model
model.compile(optimizer='sgd', loss = 'mean_squared_error')

#step4 : Train the model
model.fit(x, y, epochs = 10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - loss: 90.7701
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 63.0398
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 43.7980
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 30.4462
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 21.1814
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 14.7524
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 10.2911
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 7.1951
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 5.0466
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.5555

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# convert List to numpy arrays
x= np.array([1,2,3,4], dtype = float)
y = np.array([2,4,6,8], dtype = float)

# Define teh model
model = Sequential([
    Dense(1, input_shape = (1,))
])

#compile the model
model.compile(optimizer='sgd', loss ='mse')

#train the model
model.fit(x,y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 44.3411
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 30.7949
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 21.3953
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 14.8730
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 10.3471
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 7.2065
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5.0272
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.5148
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2.4653
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.7369

# %%
import torch
import torch.nn as nn
import torch.optim as optim

#Define a simple linear model
model = nn.Linear(1,1)


#loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = 0.01)

# dUmmy data
x = torch.tensor([[1.], [2.], [3.], [4.]])
y = torch.tensor([[2.], [4.], [6.], [8.]])

# training loop
for epoch in range(10):
  optimizer.zero_grad()
  outputs = model(x)
  loss = criterion(outputs, y)
  loss.backward()
  optimizer.step()
  print(f'Epoch {epoch+1}, Loss: {loss.item()}')
# Out:
# Epoch 1, Loss: 36.362060546875
# Epoch 2, Loss: 25.247356414794922
# Epoch 3, Loss: 17.53499984741211
# Epoch 4, Loss: 12.183462142944336
# Epoch 5, Loss: 8.470046043395996
# Epoch 6, Loss: 5.893286228179932
# Epoch 7, Loss: 4.105232238769531
# Epoch 8, Loss: 2.8644440174102783
# Epoch 9, Loss: 2.0033912658691406
# Epoch 10, Loss: 1.4058316946029663
